# %% [markdown]
# ![](Screenshot1.png)

# %% [markdown]
# from IPython.display import image
# Image("This PC\Pictures\Screenshots\Screenshot(1).png")

# %% [markdown]
# ![](sharath.png)

# %% [markdown]
# ![]("Desktop\images\sharath.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sharath/Desktop/images/sharath.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sharath/Pictures/Screenshots/Java.png")

# %%
import ipywidgets as wg
from IPython.display import display
num=wg.FloatSlider(description='Number:')
display(num)
# Out:
# FloatSlider(value=0.0, description='Number:')

# %%
print(num.value)
# Out:
# 0.0

# %%
a=wg.FloatText()
b=wg.FloatSlider()
display(a,b)
link=wg.jslink((a,"value"),(b,"value"))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)
